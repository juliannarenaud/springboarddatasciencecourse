# %%
''' import necessary packages (pandas, json) '''
import pandas as pd
import json
from pandas.io.json import json_normalize

# load in the json file as Pandas dataframe & check the file

json_df = pd.read_json('data/world_bank_projects.json')
json_df.head()
# Out:
#                                       _id  approvalfy board_approval_month  \
# 0  {u'$oid': u'52b213b38594d8a2be17c780'}        1999             November
# 1  {u'$oid': u'52b213b38594d8a2be17c781'}        2015             November
# 2  {u'$oid': u'52b213b38594d8a2be17c782'}        2014             November
# 3  {u'$oid': u'52b213b38594d8a2be17c783'}        2014              October
# 4  {u'$oid': u'52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# ...

# %%
'''Check the size of the file'''
json_df.shape
# Out:
# (500, 50)

# %%
'''Data exploration of the file'''
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
# _id                         500 non-null object
# approvalfy                  500 non-null int64
# board_approval_month        500 non-null object
# boardapprovaldate           500 non-null object
# borrower                    485 non-null object
# closingdate                 370 non-null object
# country_namecode            500 non-null object
# countrycode                 500 non-null object
# countryname                 500 non-null object
# countryshortname            500 non-null object
# docty                       446 non-null object
# envassesmentcategorycode    430 non-null object
# grantamt                    500 non-null int64
# ibrdcommamt                 500 non-null int64
# id                          500 non-null object
# idacommamt                  500 non-null int64
# impagency                   472 non-null object
# ...

# %%
'''
Question 1: Find the 10 countries with the most projects.

Approach: 
1. Identify which columns country unique country identifiers from the info above
    (country_namecode, countrycode, countryname, countryshortname)
2. Confirm from the info above that each of those four columns all contain 500 entries
3. Utilize .unique() on each of the four columns to review the contents of each column (left one example below). 
'''
json_df.countryshortname.unique()
# Out:
# array([u'Ethiopia', u'Tunisia', u'Tuvalu', u'Yemen, Republic of',
#        u'Lesotho', u'Kenya', u'India', u'China', u'Morocco',
#        u'South Sudan', u'Ghana', u'Timor-Leste', u'Jordan', u'Samoa',
#        u'Madagascar', u'Cambodia', u'Kyrgyz Republic', u'Nepal',
#        u'Tajikistan', u'Azerbaijan', u'East Asia and Pacific',
#        u"Lao People's Democratic Republic", u'Pacific Islands',
#        u'Solomon Islands', u'Mozambique', u'Angola', u'Tanzania',
#        u'Nigeria', u'Seychelles', u'Bangladesh', u'Senegal', u'Myanmar',
#        u'West Bank and Gaza', u'Argentina', u'Gambia, The',
#        u'Russian Federation', u'Congo, Republic of',
#        u'Sao Tome and Principe', u'Africa', u'Ukraine', u'Comoros',
#        u'Colombia', u"Cote d'Ivoire", u'Sierra Leone', u'World', u'Peru',
#        u'Ecuador', u'Honduras', u'Afghanistan', u'Mauritania', u'Lebanon',
#        u'Burkina Faso', u'Marshall Islands', u'Liberia', u'Zimbabwe',
# ...

# %%
'''
4. Utilize .nunique to make sure that each of the four columns had the same number of unique entries. 
Each had 118 unique entries (left one example below).
'''
json_df.countryshortname.nunique()
# Out:
# 118

# %%
'''
5. Selected the countryshortname for question 1. answer
'''

json_df.countryshortname.value_counts()[:10]
# Out:
# China                 19
# Indonesia             19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Morocco               12
# Bangladesh            12
# Nepal                 12
# Africa                11
# Mozambique            11
# Name: countryshortname, dtype: int64

# %%
'''
Question 2: Find top 10 major project themes (using column 'mjtheme_namecode').

Approach: 
1. Identify the 'mjtheme_namecode' column in the info above and confirm that the column contains 500 entries.
2. Since 'mjtheme_namecode' isn't in the .head() preview above, I wanted to preview the first few rows of that column
    to identify the contents of the column.
'''

json_df['mjtheme_namecode'][:5]
# Out:
# 0    [{u'code': u'8', u'name': u'Human development'...
# 1    [{u'code': u'1', u'name': u'Economic managemen...
# 2    [{u'code': u'5', u'name': u'Trade and integrat...
# 3    [{u'code': u'7', u'name': u'Social dev/gender/...
# 4    [{u'code': u'5', u'name': u'Trade and integrat...
# Name: mjtheme_namecode, dtype: object

# %%
'''
Based on the preview, will need to create a normalized dataframe from this nested string. 
3. Load string.
4. Use normalization to create tables from the nested element.
'''

json_data = json.load(open('data/world_bank_projects.json'))
projects = json_normalize(json_data, 'mjtheme_namecode')
projects[:25]
# Out:
#    code                                          name
# 0     8                             Human development
# 1    11
# 2     1                           Economic management
# 3     6         Social protection and risk management
# 4     5                         Trade and integration
# 5     2                      Public sector governance
# 6    11  Environment and natural resources management
# 7     6         Social protection and risk management
# 8     7                   Social dev/gender/inclusion
# 9     7                   Social dev/gender/inclusion
# 10    5                         Trade and integration
# 11    4      Financial and private sector development
# 12    6         Social protection and risk management
# 13    6
# 14    2                      Public sector governance
# 15    4      Financial and private sector development
# 16   11  Environment and natural resources management
# 17    8
# 18   10                             Rural development
# 19    7
# ...

# %%
'''
5. Since not all of the names are populated, for #2 we will identify the top 10 project themes by their code'''
projects.code.value_counts()[:10]
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %%
'''
Question 3: In 2. above you will notice that some entries have only the code and the name is missing.
Create a dataframe with the missing names filled in.

Approach: 
1. Sort by code, then name
'''

projects = projects.sort_values(['code', 'name'])
projects[:20]
# Out:
#      code                 name
# 212     1
# 363     1
# 1024    1
# 1114    1
# 1437    1
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management
# 220     1  Economic management
# 222     1  Economic management
# 223     1  Economic management
# 249     1  Economic management
# 357     1  Economic management
# 453     1  Economic management
# 454     1  Economic management
# 458     1  Economic management
# 497     1  Economic management
# 647     1  Economic management

# %%
'''2. Then replace the empty name fields with NaN'''
projects = projects.replace('', np.nan)
projects[:20]
# Out:
#      code                 name
# 212     1                  NaN
# 363     1                  NaN
# 1024    1                  NaN
# 1114    1                  NaN
# 1437    1                  NaN
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management
# 220     1  Economic management
# 222     1  Economic management
# 223     1  Economic management
# 249     1  Economic management
# 357     1  Economic management
# 453     1  Economic management
# 454     1  Economic management
# 458     1  Economic management
# 497     1  Economic management
# 647     1  Economic management

# %%
'''3. Utilize backfill to fill in the names for the NaN names'''
projects = projects.fillna(method='bfill')
projects[:20]
# Out:
#      code                 name
# 212     1  Economic management
# 363     1  Economic management
# 1024    1  Economic management
# 1114    1  Economic management
# 1437    1  Economic management
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management
# 220     1  Economic management
# 222     1  Economic management
# 223     1  Economic management
# 249     1  Economic management
# 357     1  Economic management
# 453     1  Economic management
# 454     1  Economic management
# 458     1  Economic management
# 497     1  Economic management
# 647     1  Economic management

# %%
'''
4. Rerun the counts from step 2, but this time utilizing the name field.
5. Compare the numbers to those from the code count to ensure that the numbers match'''
projects.name.value_counts()[:10]
# Out:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Name: name, dtype: int64
